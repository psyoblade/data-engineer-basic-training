-- %%
mysql://scott:tiger@mysql:3306/default

-- %%
show tables;
-- Out:
-- <table border="1" class="dataframe">
--   <thead>
--     <tr style="text-align: right;">
--       <th></th>
--       <th>Tables_in_default</th>
--     </tr>
--   </thead>
--   <tbody>
--     <tr>
--       <th>0</th>
--       <td>castings</td>
--     </tr>
--     <tr>
--       <th>1</th>
--       <td>countries</td>
--     </tr>
--     <tr>
--       <th>2</th>
--       <td>genres</td>
--     </tr>
--     <tr>
--       <th>3</th>
--       <td>movies</td>
--     </tr>
--     <tr>
--       <th>4</th>
--       <td>peoples</td>
--     </tr>
--     <tr>
--       <th>5</th>
--       <td>purchase_20201025</td>
--     </tr>
--     <tr>
--       <th>6</th>
--       <td>purchase_20201026</td>
--     </tr>
--     <tr>
--       <th>7</th>
--       <td>rates</td>
--     </tr>
--     <tr>
--       <th>8</th>
--       <td>seoul_popular_trip</td>
--     </tr>
--     <tr>
--       <th>9</th>
--       <td>user_20201025</td>
--     </tr>
--     <tr>
--       <th>10</th>
--       <td>user_20201026</td>
-- ...

-- %%
select * from seoul_popular_trip limit 10;
-- Out:
-- <table border="1" class="dataframe">
--   <thead>
--     <tr style="text-align: right;">
--       <th></th>
--       <th>category</th>
--       <th>id</th>
--       <th>name</th>
--       <th>address</th>
--       <th>naddress</th>
--       <th>tel</th>
--       <th>tag</th>
--     </tr>
--   </thead>
--   <tbody>
--     <tr>
--       <th>0</th>
--       <td>0</td>
--       <td>281</td>
--       <td>통인시장</td>
--       <td>110-043 서울 종로구 통인동 10-3</td>
--       <td>03036 서울 종로구 자하문로15길 18</td>
--       <td>02-722-0911</td>
--       <td>엽전도시락,종로통인시장,통인시장닭꼬치,런닝맨,엽전시장,통인시장데이트,효자베이커리,통인시장, 1박2일,기름떡볶이</td>
--     </tr>
--     <tr>
--       <th>1</th>
--       <td>0</td>
--       <td>345</td>
--       <td>타르틴</td>
--       <td>140-863 서울 용산구 이태원동 119-15</td>
--       <td>04350 서울 용산구 이태원로23길 4 (이태원동)</td>
--       <td>02-3785-3400</td>
--       <td>타르틴,이태원디저트카페,파이,런닝맨,파이맛집,이태원맛집, 유재석,식신로드,타르트맛집</td>
--     </tr>
--     <tr>
--       <th>2</th>
--       <td>0</td>
--       <td>383</td>
-- ...

-- %%
desc foo
-- Out:
-- <table border="1" class="dataframe">
--   <thead>
--     <tr style="text-align: right;">
--       <th></th>
--       <th>Field</th>
--       <th>Type</th>
--       <th>Null</th>
--       <th>Key</th>
--       <th>Default</th>
--       <th>Extra</th>
--     </tr>
--   </thead>
--   <tbody>
--     <tr>
--       <th>0</th>
--       <td>id</td>
--       <td>int(11)</td>
--       <td>YES</td>
--       <td></td>
--       <td>None</td>
--       <td></td>
--     </tr>
--     <tr>
--       <th>1</th>
--       <td>name</td>
--       <td>varchar(50)</td>
--       <td>YES</td>
--       <td></td>
--       <td>None</td>
--       <td></td>
--     </tr>
--   </tbody>
-- </table>

-- %%
create table foo (id int, name varchar(50));

-- %% [markdown]
-- ```
-- movies
--  |-- movie: integer (nullable = true)
--  |-- title: string (nullable = true)
--  |-- title_eng: string (nullable = true)
--  |-- year: integer (nullable = true)
--  |-- grade: string (nullable = true)
--
-- peoples
--  |-- people: integer (nullable = true)
--  |-- korean: string (nullable = true)
--  |-- original: string (nullable = true)
--
-- castings
--  |-- movie: integer (nullable = true)
--  |-- people: integer (nullable = true)
--  |-- order: integer (nullable = true)
--  |-- leading: integer (nullable = true)
--
-- countries
--  |-- movie: integer (nullable = true)
--  |-- country: string (nullable = true)
--
-- genres
--  |-- movie: integer (nullable = true)
--  |-- genre: string (nullable = true)
--
-- rates
--  |-- user: integer (nullable = true)
--  |-- movie: integer (nullable = true)
--  |-- rate: integer (nullable = true)
--  |-- time: integer (nullable = true)
-- ```

-- %%
create table if not exists movies (movie int, title varchar(255), title_eng varchar(255), year int, grade varchar(50));

-- %%
create table if not exists peoples (people int, korean varchar(255), original varchar(255));

-- %%
create table if not exists castings (movie int, people int, `order` int, `leading` int);

-- %%
create table if not exists countries (movie int, country varchar(255));

-- %%
create table if not exists genres (movie int, genre varchar(50));

-- %%
create table if not exists rates (user int, movie int, rate int, `time` int, `timestamp` varchar(50));
-- Out:
-- This result object does not return rows. It has been closed automatically.

-- %%
select * from movies limit 10;
-- Out:
-- <table border="1" class="dataframe">
--   <thead>
--     <tr style="text-align: right;">
--       <th></th>
--       <th>movie</th>
--       <th>title</th>
--       <th>title_eng</th>
--       <th>year</th>
--       <th>grade</th>
--     </tr>
--   </thead>
--   <tbody>
--     <tr>
--       <th>0</th>
--       <td>10001</td>
--       <td>시네마 천국</td>
--       <td>Cinema Paradiso , 1988</td>
--       <td>2013.0</td>
--       <td>전체 관람가</td>
--     </tr>
--     <tr>
--       <th>1</th>
--       <td>10002</td>
--       <td>빽 투 더 퓨쳐</td>
--       <td>Back To The Future , 1985</td>
--       <td>2015.0</td>
--       <td>12세 관람가</td>
--     </tr>
--     <tr>
--       <th>2</th>
--       <td>10003</td>
--       <td>빽 투 더 퓨쳐 2</td>
--       <td>Back To The Future Part 2 , 1989</td>
--       <td>2015.0</td>
--       <td>12세 관람가</td>
--     </tr>
--     <tr>
--       <th>3</th>
--       <td>10004</td>
--       <td>빽 투 더 퓨쳐 3</td>
--       <td>Back To The Future Part III , 1990</td>
-- ...

-- %%
select * from peoples limit 10;
-- Out:
-- <table border="1" class="dataframe">
--   <thead>
--     <tr style="text-align: right;">
--       <th></th>
--       <th>movie</th>
--       <th>people</th>
--       <th>order</th>
--       <th>leading</th>
--     </tr>
--   </thead>
--   <tbody>
--     <tr>
--       <th>0</th>
--       <td>10001</td>
--       <td>4374</td>
--       <td>1</td>
--       <td>1</td>
--     </tr>
--     <tr>
--       <th>1</th>
--       <td>10001</td>
--       <td>178</td>
--       <td>2</td>
--       <td>1</td>
--     </tr>
--     <tr>
--       <th>2</th>
--       <td>10001</td>
--       <td>3241</td>
--       <td>3</td>
--       <td>1</td>
--     </tr>
--     <tr>
--       <th>3</th>
--       <td>10001</td>
--       <td>47952</td>
--       <td>4</td>
--       <td>1</td>
--     </tr>
--     <tr>
--       <th>4</th>
--       <td>10001</td>
--       <td>47953</td>
--       <td>5</td>
--       <td>0</td>
--     </tr>
--     <tr>
--       <th>5</th>
--       <td>10001</td>
--       <td>19538</td>
-- ...

-- %%
select * from castings limit 10;
-- Out:
-- <table border="1" class="dataframe">
--   <thead>
--     <tr style="text-align: right;">
--       <th></th>
--       <th>movie</th>
--       <th>people</th>
--       <th>order</th>
--       <th>leading</th>
--     </tr>
--   </thead>
--   <tbody>
--     <tr>
--       <th>0</th>
--       <td>10001</td>
--       <td>4374</td>
--       <td>1</td>
--       <td>1</td>
--     </tr>
--     <tr>
--       <th>1</th>
--       <td>10001</td>
--       <td>178</td>
--       <td>2</td>
--       <td>1</td>
--     </tr>
--     <tr>
--       <th>2</th>
--       <td>10001</td>
--       <td>3241</td>
--       <td>3</td>
--       <td>1</td>
--     </tr>
--     <tr>
--       <th>3</th>
--       <td>10001</td>
--       <td>47952</td>
--       <td>4</td>
--       <td>1</td>
--     </tr>
--     <tr>
--       <th>4</th>
--       <td>10001</td>
--       <td>47953</td>
--       <td>5</td>
--       <td>0</td>
--     </tr>
--     <tr>
--       <th>5</th>
--       <td>10001</td>
--       <td>19538</td>
-- ...

-- %%
select * from countries limit 10;
-- Out:
-- <table border="1" class="dataframe">
--   <thead>
--     <tr style="text-align: right;">
--       <th></th>
--       <th>movie</th>
--       <th>country</th>
--     </tr>
--   </thead>
--   <tbody>
--     <tr>
--       <th>0</th>
--       <td>10001</td>
--       <td>이탈리아</td>
--     </tr>
--     <tr>
--       <th>1</th>
--       <td>10001</td>
--       <td>프랑스</td>
--     </tr>
--     <tr>
--       <th>2</th>
--       <td>10002</td>
--       <td>미국</td>
--     </tr>
--     <tr>
--       <th>3</th>
--       <td>10003</td>
--       <td>미국</td>
--     </tr>
--     <tr>
--       <th>4</th>
--       <td>10004</td>
--       <td>미국</td>
--     </tr>
--     <tr>
--       <th>5</th>
--       <td>10005</td>
--       <td>미국</td>
--     </tr>
--     <tr>
--       <th>6</th>
--       <td>10006</td>
--       <td>미국</td>
--     </tr>
--     <tr>
--       <th>7</th>
--       <td>10007</td>
--       <td>미국</td>
--     </tr>
--     <tr>
--       <th>8</th>
--       <td>10008</td>
-- ...

-- %%
select * from genres limit 10;
-- Out:
-- <table border="1" class="dataframe">
--   <thead>
--     <tr style="text-align: right;">
--       <th></th>
--       <th>movie</th>
--       <th>genre</th>
--     </tr>
--   </thead>
--   <tbody>
--     <tr>
--       <th>0</th>
--       <td>10001</td>
--       <td>드라마</td>
--     </tr>
--     <tr>
--       <th>1</th>
--       <td>10001</td>
--       <td>멜로/로맨스</td>
--     </tr>
--     <tr>
--       <th>2</th>
--       <td>10002</td>
--       <td>SF</td>
--     </tr>
--     <tr>
--       <th>3</th>
--       <td>10002</td>
--       <td>코미디</td>
--     </tr>
--     <tr>
--       <th>4</th>
--       <td>10003</td>
--       <td>SF</td>
--     </tr>
--     <tr>
--       <th>5</th>
--       <td>10003</td>
--       <td>코미디</td>
--     </tr>
--     <tr>
--       <th>6</th>
--       <td>10004</td>
--       <td>서부</td>
--     </tr>
--     <tr>
--       <th>7</th>
--       <td>10004</td>
--       <td>SF</td>
--     </tr>
--     <tr>
--       <th>8</th>
--       <td>10004</td>
-- ...

-- %%
select * from rates limit 10;
-- Out:
-- <table border="1" class="dataframe">
--   <thead>
--     <tr style="text-align: right;">
--       <th></th>
--       <th>user</th>
--       <th>movie</th>
--       <th>rate</th>
--       <th>time</th>
--     </tr>
--   </thead>
--   <tbody>
--     <tr>
--       <th>0</th>
--       <td>0</td>
--       <td>10003</td>
--       <td>7</td>
--       <td>1494128040</td>
--     </tr>
--     <tr>
--       <th>1</th>
--       <td>0</td>
--       <td>10004</td>
--       <td>7</td>
--       <td>1467529800</td>
--     </tr>
--     <tr>
--       <th>2</th>
--       <td>0</td>
--       <td>10018</td>
--       <td>9</td>
--       <td>1513344120</td>
--     </tr>
--     <tr>
--       <th>3</th>
--       <td>0</td>
--       <td>10021</td>
--       <td>9</td>
--       <td>1424497980</td>
--     </tr>
--     <tr>
--       <th>4</th>
--       <td>0</td>
--       <td>10022</td>
--       <td>7</td>
--       <td>1427627340</td>
--     </tr>
--     <tr>
--       <th>5</th>
--       <td>0</td>
-- ...

-- %%
desc rates;
-- Out:
-- <table border="1" class="dataframe">
--   <thead>
--     <tr style="text-align: right;">
--       <th></th>
--       <th>Field</th>
--       <th>Type</th>
--       <th>Null</th>
--       <th>Key</th>
--       <th>Default</th>
--       <th>Extra</th>
--     </tr>
--   </thead>
--   <tbody>
--     <tr>
--       <th>0</th>
--       <td>user</td>
--       <td>int(11)</td>
--       <td>YES</td>
--       <td></td>
--       <td>None</td>
--       <td></td>
--     </tr>
--     <tr>
--       <th>1</th>
--       <td>movie</td>
--       <td>int(11)</td>
--       <td>YES</td>
--       <td></td>
--       <td>None</td>
--       <td></td>
--     </tr>
--     <tr>
--       <th>2</th>
--       <td>rate</td>
--       <td>int(11)</td>
--       <td>YES</td>
--       <td></td>
--       <td>None</td>
--       <td></td>
--     </tr>
--     <tr>
--       <th>3</th>
--       <td>time</td>
--       <td>int(11)</td>
--       <td>YES</td>
--       <td></td>
--       <td>None</td>
--       <td></td>
-- ...
